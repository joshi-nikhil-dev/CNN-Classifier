# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, f1_score
import optuna  # Import Optuna

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Custom dataset class for folder-structured data
class AgeFolderDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        
        for folder_name in os.listdir(root_dir):
            folder_path = os.path.join(root_dir, folder_name)
            if os.path.isdir(folder_path):
                age = int(folder_name)
                for img_name in os.listdir(folder_path):
                    if img_name.endswith('.jpg') or img_name.endswith('.png'):
                        img_path = os.path.join(folder_path, img_name)
                        self.data.append((img_path, age))
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_path, age = self.data[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, torch.tensor(age, dtype=torch.float)

# Define transforms for preprocessing
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Create the dataset
dataset = AgeFolderDataset(root_dir='assessment-data', transform=transform)

# Split the dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Define a custom CNN model for age classification
class CustomAgeCNN(nn.Module):
    def __init__(self):
        super(CustomAgeCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(128 * 16 * 16, 512)
        self.fc2 = nn.Linear(512, 1)
        self.dropout = nn.Dropout(0.5)
    
    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = x.view(-1, 128 * 16 * 16)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Define the objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)

    # Data loaders with suggested batch size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    model = CustomAgeCNN().to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Training loop
    epochs = 100
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()
            optimizer.zero_grad()
            outputs = model(inputs).squeeze()
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)

    # Validation loop
    model.eval()
    val_loss = 0.0
    predictions, actuals = [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()
            outputs = model(inputs).squeeze()
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            predictions.extend(torch.round(outputs).cpu().numpy())
            actuals.extend(labels.cpu().numpy())

    val_loss = val_loss / len(val_loader.dataset)
    mae = mean_absolute_error(actuals, predictions)

    # Return the Mean Absolute Error as the metric to minimize
    return mae

# Create a study and optimize the objective function
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)  # Run 50 trials

# Print the best hyperparameters
print("Best hyperparameters:", study.best_params)

# Optionally, you can plot the optimization history
optuna.visualization.plot_optimization_history(study)
plt.show()
# Out:
# [I 2024-09-27 00:51:47,704] A new study created in memory with name: no-name-efe4e4f2-b8ca-4e60-8302-135dedc3db39
# Using device: cuda
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 00:53:01,782] Trial 0 finished with value: 7.714285850524902 and parameters: {'batch_size': 32, 'learning_rate': 0.006332308859187653}. Best is trial 0 with value: 7.714285850524902.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 00:54:13,303] Trial 1 finished with value: 14.428571701049805 and parameters: {'batch_size': 32, 'learning_rate': 1.8863779969785924e-05}. Best is trial 0 with value: 7.714285850524902.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 00:55:19,193] Trial 2 finished with value: 13.357142448425293 and parameters: {'batch_size': 64, 'learning_rate': 0.001001170093298745}. Best is trial 0 with value: 7.714285850524902.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 00:56:35,611] Trial 3 finished with value: 4.9285712242126465 and parameters: {'batch_size': 16, 'learning_rate': 0.002730262947508713}. Best is trial 3 with value: 4.9285712242126465.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 00:57:52,212] Trial 4 finished with value: 3.142857074737549 and parameters: {'batch_size': 16, 'learning_rate': 0.0001377297299018474}. Best is trial 4 with value: 3.142857074737549.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 00:58:57,627] Trial 5 finished with value: 13.285714149475098 and parameters: {'batch_size': 64, 'learning_rate': 0.03232896567423417}. Best is trial 4 with value: 3.142857074737549.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:00:14,571] Trial 6 finished with value: 3.0 and parameters: {'batch_size': 16, 'learning_rate': 0.00014928554132263698}. Best is trial 6 with value: 3.0.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:01:26,710] Trial 7 finished with value: 14.0 and parameters: {'batch_size': 32, 'learning_rate': 0.007435490909669956}. Best is trial 6 with value: 3.0.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:02:43,717] Trial 8 finished with value: 13.785714149475098 and parameters: {'batch_size': 16, 'learning_rate': 1.9480652357848554e-05}. Best is trial 6 with value: 3.0.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:03:59,655] Trial 9 finished with value: 3.142857074737549 and parameters: {'batch_size': 16, 'learning_rate': 0.006234217059053804}. Best is trial 6 with value: 3.0.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:05:24,958] Trial 10 finished with value: 2.857142925262451 and parameters: {'batch_size': 16, 'learning_rate': 0.00015005064914985506}. Best is trial 10 with value: 2.857142925262451.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01

# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:36:04,446] Trial 35 finished with value: 2.2857143878936768 and parameters: {'batch_size': 16, 'learning_rate': 0.0009352957460118412}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:37:19,852] Trial 36 finished with value: 7.642857074737549 and parameters: {'batch_size': 16, 'learning_rate': 7.991145066620704e-05}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:38:23,959] Trial 37 finished with value: 5.4285712242126465 and parameters: {'batch_size': 64, 'learning_rate': 0.00083215728855734}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:39:34,023] Trial 38 finished with value: 15.0 and parameters: {'batch_size': 32, 'learning_rate': 1.030323056132871e-05}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:40:48,594] Trial 39 finished with value: 3.357142925262451 and parameters: {'batch_size': 16, 'learning_rate': 0.000244171059696614}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:42:03,903] Trial 40 finished with value: 13.785714149475098 and parameters: {'batch_size': 16, 'learning_rate': 2.8696413690884474e-05}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:43:19,860] Trial 41 finished with value: 3.2857143878936768 and parameters: {'batch_size': 16, 'learning_rate': 0.0008148106640033449}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:44:35,186] Trial 42 finished with value: 3.2857143878936768 and parameters: {'batch_size': 16, 'learning_rate': 0.0017763928514270605}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:45:50,326] Trial 43 finished with value: 14.857142448425293 and parameters: {'batch_size': 16, 'learning_rate': 0.0035682790830640306}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:47:05,497] Trial 44 finished with value: 2.5 and parameters: {'batch_size': 16, 'learning_rate': 0.0008145397152943232}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:48:20,116] Trial 45 finished with value: 5.9285712242126465 and parameters: {'batch_size': 16, 'learning_rate': 0.00010225714015106985}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:49:34,686] Trial 46 finished with value: 4.4285712242126465 and parameters: {'batch_size': 16, 'learning_rate': 0.00024196292656430954}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:50:50,112] Trial 47 finished with value: 5.0 and parameters: {'batch_size': 16, 'learning_rate': 0.0006592589765880497}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:51:53,871] Trial 48 finished with value: 14.0 and parameters: {'batch_size': 64, 'learning_rate': 0.0013288719520549524}. Best is trial 35 with value: 2.2857143878936768.
# C:\Users\joshi\AppData\Local\Temp\ipykernel_18088\3213268391.py:83: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# [I 2024-09-27 01:53:08,519] Trial 49 finished with value: 2.7142856121063232 and parameters: {'batch_size': 16, 'learning_rate': 0.0003469600641885755}. Best is trial 35 with value: 2.2857143878936768.
# Best hyperparameters: {'batch_size': 16, 'learning_rate': 0.0009352957460118412}
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\tor\Lib\site-packages\optuna\visualization\_plotly_imports.py:7
#       6 with try_import() as _imports:
# ----> 7     import plotly
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 137
#     134 print("Best hyperparameters:", study.best_params)
#     136 # Optionally, you can plot the optimization history
# --> 137 optuna.visualization.plot_optimization_history(study)
#     138 plt.show()
#
# File ~\AppData\Local\anaconda3\envs\tor\Lib\site-packages\optuna\visualization\_optimization_history.py:200, in plot_optimization_history(study, target, target_name, error_bar)
#     172 def plot_optimization_history(
#     173     study: Study | Sequence[Study],
#     174     *,
#    (...)
#     177     error_bar: bool = False,
#     178 ) -> "go.Figure":
#     179     """Plot optimization history of all trials in a study.
#     180
#     181     Args:
#    (...)
#     197         A :class:`plotly.graph_objects.Figure` object.
#     198     """
# --> 200     _imports.check()
#     202     info_list = _get_optimization_history_info_list(study, target, target_name, error_bar)
#     203     return _get_optimization_history_plot(info_list, target_name)
#
# File ~\AppData\Local\anaconda3\envs\tor\Lib\site-packages\optuna\_imports.py:95, in _DeferredImportExceptionContextManager.check(self)
#      93 if self._deferred is not None:
#      94     exc_value, message = self._deferred
# ---> 95     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, f1_score

# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Custom dataset class for folder-structured data
class AgeFolderDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        
        for folder_name in os.listdir(root_dir):
            folder_path = os.path.join(root_dir, folder_name)
            if os.path.isdir(folder_path):
                age = int(folder_name)  # The folder name is the age
                for img_name in os.listdir(folder_path):
                    if img_name.endswith('.jpg') or img_name.endswith('.png'):
                        img_path = os.path.join(folder_path, img_name)
                        self.data.append((img_path, age))
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        img_path, age = self.data[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, torch.tensor(age, dtype=torch.float)

# Define transforms
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Create the dataset
dataset = AgeFolderDataset(root_dir='assessment-data', transform=transform)

# Split the dataset into training and validation sets (80% train, 20% validation)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Define a custom CNN model
class CustomAgeCNN(nn.Module):
    def __init__(self):
        super(CustomAgeCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(128 * 16 * 16, 512)
        self.fc2 = nn.Linear(512, 1)
        self.dropout = nn.Dropout(0.5)
    
    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = x.view(-1, 128 * 16 * 16)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Set hyperparameters from tuning results
best_batch_size = 16
best_learning_rate = 0.0009352957460118412

# Data loaders with the best batch size
train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)

# Initialize model, loss function, and optimizer
model = CustomAgeCNN().to(device)
criterion = nn.MSELoss()  # Mean Squared Error loss for regression
optimizer = optim.Adam(model.parameters(), lr=best_learning_rate)

# Lists to store training and validation loss
train_losses = []
val_losses = []

# Training loop
epochs = 100
for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).float()
        
        # Forward pass
        optimizer.zero_grad()
        outputs = model(inputs).squeeze()
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)
    print(f'Epoch {epoch+1}/{epochs}, Loss: {epoch_loss}')
    
    # Validation loop
    model.eval()
    val_loss = 0.0
    predictions, actuals = [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device).float()
            outputs = model(inputs).squeeze()
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            predictions.extend(torch.round(outputs).cpu().numpy())
            actuals.extend(labels.cpu().numpy())
    
    val_loss = val_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    print(f'Validation Loss: {val_loss}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(actuals, predictions)
print(f'Mean Absolute Error: {mae}')

# Calculate F1 Score (binarized for example)
f1 = f1_score(actuals, predictions, average='macro')
print(f'F1 Score: {f1}')

# Plotting the training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
plt.plot(range(1, epochs + 1), val_losses, label='Validation Loss')
plt.title('Train and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()
# Out:
# Using device: cuda
# Epoch 1/100, Loss: 1803.0014125279017
# Validation Loss: 326.2620544433594
# Epoch 2/100, Loss: 705.5545479910714
# Validation Loss: 1075.6630859375
# Epoch 3/100, Loss: 566.7923671177456
# Validation Loss: 445.8736877441406
# Epoch 4/100, Loss: 688.7397722516741
# Validation Loss: 706.2833862304688
# Epoch 5/100, Loss: 776.977294921875
# Validation Loss: 1051.347412109375
# Epoch 6/100, Loss: 488.8158046177455
# Validation Loss: 494.73626708984375
# Epoch 7/100, Loss: 668.1399274553571
# Validation Loss: 483.26837158203125
# Epoch 8/100, Loss: 487.0031999860491
# Validation Loss: 949.98828125
# Epoch 9/100, Loss: 595.6604614257812
# Validation Loss: 470.9897766113281
# Epoch 10/100, Loss: 437.0464303152902
# Validation Loss: 401.3282775878906
# Epoch 11/100, Loss: 426.2190420968192
# Validation Loss: 627.3796997070312
# Epoch 12/100, Loss: 425.854012625558
# Validation Loss: 587.5430908203125
# Epoch 13/100, Loss: 437.87418038504467
# Validation Loss: 419.9586486816406
# Epoch 14/100, Loss: 469.38033621651783
# Validation Loss: 461.1329345703125
# Epoch 15/100, Loss: 409.01464407784596
# Validation Loss: 579.0859375
# Epoch 16/100, Loss: 355.3888898577009
# Validation Loss: 494.33038330078125
# Epoch 17/100, Loss: 394.0581272670201
# Validation Loss: 487.56207275390625
# Epoch 18/100, Loss: 347.31175449916293
# Validation Loss: 645.8902587890625
# Epoch 19/100, Loss: 356.2820739746094
# Validation Loss: 468.126220703125
# Epoch 20/100, Loss: 350.6095232282366
# Validation Loss: 475.36029052734375
# Epoch 21/100, Loss: 321.5136413574219
# Validation Loss: 595.2687377929688
# Epoch 22/100, Loss: 337.52310616629467
# Validation Loss: 488.1138610839844
# Epoch 23/100, Loss: 281.962166922433
